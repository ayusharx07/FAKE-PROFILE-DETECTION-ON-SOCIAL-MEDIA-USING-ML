# %%
# !pip install pandas
import pandas as pd

# Load datasets
fake_df = pd.read_csv("fake_users.csv")
real_df = pd.read_csv("real_users.csv")

# Check dataset shape
print("Fake Dataset Shape :", fake_df.shape)
print("Real Dataset Shape :", real_df.shape)

# Verify columns
print("Same Columns :", fake_df.columns.equals(real_df.columns))

# Add labels
fake_df["label"] = 1
real_df["label"] = 0

# Merge datasets
df = pd.concat([fake_df, real_df], ignore_index=True)

# Final dataset shape
print("Final Dataset Shape :", df.shape)

# Count classes
print("Fake Profiles :", (df["label"] == 1).sum())
print("Genuine Profiles :", (df["label"] == 0).sum())

# Preview dataset
print(df.head())

# Dataset information
df.info()

# Missing values
print(df.isnull().sum())

# Save final dataset
df.to_csv("final_fake_profile_dataset.csv", index=False)

print("Dataset saved successfully!")
# Out:
# Requirement already satisfied: pandas in c:\users\hp\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\hp\anaconda3\lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\hp\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Fake Dataset Shape : (2500, 34)
# Real Dataset Shape : (2500, 34)
# Same Columns : True
# Final Dataset Shape : (5000, 35)
# Fake Profiles : 2500
# Genuine Profiles : 2500
#              id             name  screen_name  statuses_count  \
# 0  1.664073e+09    Lavona Keller    kellervxg       13.093733
# 1  7.296345e+08  Elizabet Graves          NaN        0.000000
# 2  1.214885e+09   Estelle Santos  estellesant       52.941642
# 3 -0.000000e+00      Patsy Weiss     patsyyor       18.857321
# 4  1.844412e+09       Cindy Cook          NaN       51.167110
#
#    followers_count  friends_count  favourites_count  listed_count  \
# 0        -0.000000       0.000000               0.0           0.0
# 1         0.000000       0.000000               0.0           0.0
# 2        -0.000000     518.508286              -0.0          -0.0
# 3         0.000000    1059.138617               0.0           0.0
# 4         7.368223       0.000000               0.0           0.0
#
#                        created_at  url  ...  \
# 0  Sun Jun 24 03:26:11 +0000 2012 -0.0  ...
# 1  Mon Jun 25 02:06:59 +0000 2012  0.0  ...
# 2  Sat Jun 23 19:48:28 +0000 2012 -0.0  ...
# 3  Sat Jun 23 15:34:23 +0000 2012  0.0  ...
# 4                             NaN  0.0  ...
#
#                       profile_background_image_url profile_background_color  \
# 0                                              NaN                   C0DEED
# 1  http://a0.twimg.com/images/themes/theme1/bg.png                      NaN
# 2                                              NaN                   C0DEED
# 3  http://a0.twimg.com/images/themes/theme1/bg.png                   C0DEED
# 4  http://a0.twimg.com/images/themes/theme1/bg.png                      NaN
#
#   profile_link_color  utc_offset  protected  verified  \
# 0                NaN         0.0        0.0       0.0
# 1             0084B4         0.0        0.0       0.0
# 2             0084B4         0.0        0.0       0.0
# 3             0084B4         0.0        0.0       0.0
# 4                NaN         0.0        0.0      -0.0
#
#                                          description              updated  \
# 0                                 Keep moving forwad  2015-02-14 10:40:01
# 1                                                NaN  2015-02-14 10:40:01
# 2           Practical wisdom,healh, Chinese Medicine                  NaN
# 3  this is a support page or el_aminito check him...                  NaN
# 4                                                NaN                  NaN
#
#    dataset label
# 0      NaN     1
# 1      NaN     1
# 2      NaN     1
# 3      INT     1
# 4      NaN     1
#
# [5 rows x 35 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 35 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   id                                  5000 non-null   float64
#  1   name                                3260 non-null   object
#  2   screen_name                         3230 non-null   object
#  3   statuses_count                      5000 non-null   float64
#  4   followers_count                     5000 non-null   float64
#  5   friends_count                       5000 non-null   float64
#  6   favourites_count                    5000 non-null   float64
#  7   listed_count                        5000 non-null   float64
#  8   created_at                          3261 non-null   object
#  9   url                                 3014 non-null   object
#  10  lang                                3230 non-null   object
#  11  time_zone                           1121 non-null   object
#  12  location                            2681 non-null   object
#  13  default_profile                     5000 non-null   float64
#  14  default_profile_image               5000 non-null   float64
#  15  geo_enabled                         5000 non-null   float64
#  16  profile_image_url                   3211 non-null   object
#  17  profile_banner_url                  1078 non-null   object
#  18  profile_use_background_image        5000 non-null   float64
#  19  profile_background_image_url_https  3269 non-null   object
#  20  profile_text_color                  3249 non-null   object
#  21  profile_image_url_https             3231 non-null   object
#  22  profile_sidebar_border_color        3204 non-null   object
#  23  profile_background_tile             5000 non-null   float64
#  24  profile_sidebar_fill_color          3247 non-null   object
#  25  profile_background_image_url        3285 non-null   object
#  26  profile_background_color            3232 non-null   object
#  27  profile_link_color                  3248 non-null   object
#  28  utc_offset                          5000 non-null   float64
#  29  protected                           5000 non-null   float64
#  30  verified                            5000 non-null   float64
#  31  description                         2915 non-null   object
#  32  updated                             3238 non-null   object
#  33  dataset                             3254 non-null   object
#  34  label                               5000 non-null   int64
# dtypes: float64(14), int64(1), object(20)
# memory usage: 1.3+ MB
# id                                       0
# name                                  1740
# screen_name                           1770
# statuses_count                           0
# followers_count                          0
# friends_count                            0
# favourites_count                         0
# listed_count                             0
# created_at                            1739
# url                                   1986
# lang                                  1770
# time_zone                             3879
# location                              2319
# default_profile                          0
# default_profile_image                    0
# geo_enabled                              0
# profile_image_url                     1789
# profile_banner_url                    3922
# profile_use_background_image             0
# profile_background_image_url_https    1731
# profile_text_color                    1751
# profile_image_url_https               1769
# profile_sidebar_border_color          1796
# profile_background_tile                  0
# profile_sidebar_fill_color            1753
# profile_background_image_url          1715
# profile_background_color              1768
# profile_link_color                    1752
# utc_offset                               0
# protected                                0
# verified                                 0
# description                           2085
# updated                               1762
# dataset                               1746
# label                                    0
# dtype: int64
# Dataset saved successfully!
